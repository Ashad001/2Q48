# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashad001/2Q48/blob/main/QuantumRL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google QuantumAI

# %% [markdown]
# ## Install

# %%
try:
    import cirq
except ImportError:
    print("installing cirq...")
    # !pip install --quiet cirq
    print("installed cirq.")
# Out:
# installing cirq...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.7/532.7 kB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.5/596.5 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.8/202.8 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 13.5 MB/s eta 0:00:00
#   Building wheel for rpcq (setup.py) ... done
# installed cirq.

# %% [markdown]
# ## Imports

# %%
import cirq
from cirq import Simulator

# %% [markdown]
# # Imports

# %%
import time
import math
import cmath
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm
from functools import reduce
from google.colab import files
from sklearn.model_selection import ParameterGrid

# %% [markdown]
# # Introduction
#
# ## Reward
# Il principale problema è la formulzione della reward. per ora, l'unica soluzione tale da portare risultati accettabili è stata:
# - reward = "grande" per stato terminal
# - reward < 0 per stato non terminal
#
# L'aggiunta di reward negativa a punire ogni step che non portasse a uno stato terminale, è stato cruciale. Infatti, ho usato altri tipi di reward, ma tutte fallimentari
# - fidelity
# - fidelity per stato terminale, altrimenti 0
# - "grande" per stato terminale, altrimenti 0

# %% [markdown]
# ## Off Policy
# Sono dovuto ricorrere a un'approccio off policy, in quanto un approccio on policy non garantiva esplorazione sufficiente in uno spazio di ricerca così vasto. I risultati erano fortemente limitati, la matrice dei weight non vedeva mai alcune azioni, il cui valore rimaneva 0 per ogni features. I risultati erano in media peggiori di un' approccio Random.
# Andando a usare una bahaviour policy completamente randomica, e una target policy completamente greedy, i risultati sono notevolmente migliorati.

# %% [markdown]
# # Quantum Setup

# %% [markdown]
# ### Qubit

# %%
class Qubit:
  def __init__(self, amplitudes):
    """
    Args:
      amplitudes (np.array): amplitudes of the |0>, |1> vectors
    """
    error = "Error: sum of squared amplitudes must be = 1"
    assert math.isclose(reduce(lambda a, b: a+b, map(lambda a: abs(a)**2, amplitudes)), 1, rel_tol = 1e-2), error
    self._amplitudes = amplitudes

  def qubit(self):
    return self._amplitudes


class Basis(Qubit):
  def __init__(self, index):
    """
    Z operator Basis
    Args:
      index: index of the position = 1
    """
    amplitudes = np.zeros((2, ))
    amplitudes[index] += 1
    super().__init__(amplitudes)

# %% [markdown]
# ### Quantum State

# %%
class QuantumState:
  def __init__(self, amplitudes):

    # We assume computational basis
    self._basis = {
        '00': [Basis(0), Basis(0)],
        '01': [Basis(0), Basis(1)],
        '10': [Basis(1), Basis(0)],
        '11': [Basis(1), Basis(1)],
    }

    a1, a2, a3, a4 = amplitudes
    self._amplitudes = {
        '00': a1,
        '01': a2,
        '10': a3,
        '11': a4
    }

    self._keys = list(self._basis.keys())

    error = "Error: sum of squared amplitudes must be = 1"
    val = reduce(lambda a, b: a+b, map(lambda a: abs(a)**2, amplitudes))
    assert math.isclose(val, 1, rel_tol = 1e-3), error + f" instead is {val}"

  def get_amplitudes(self):
    return np.array(list(self._amplitudes.values()))

  def get_features(self):
    real = np.real(list(self.get_amplitudes()))
    imag = np.imag(list(self.get_amplitudes()))
    return np.concatenate((real, imag))

  def apply_gate(self, gate, inplace = False):
    updated_amplitudes = gate.apply(self)
    if inplace:
      self._amplitudes = updated_amplitudes
      return None

    return QuantumState(list(updated_amplitudes.values()))

  def fidelity_score(self, other):
    # Fidelity implementation from paper
    """
    Args:
      other (QuantumState): measure the fidelity between self and another quantum state
    Return:
      fidelity (float): fidelity score between [0, 1]
    """
    # Inner product can be computed in terms of matrix representation. Page 67 Nielsen-Chuang
    return np.square(abs(np.matmul(np.conj(self.get_amplitudes()), other.get_amplitudes())))

# %% [markdown]
# ### Quantum Gates

# %%
class QuantumGate:
  def __init__(self, name, unitary, target):
    """
    Args:
      unitary: 2x2 unitary operator
      target: 0 or 1 to denote the qubit the matrix is acting on
    """
    self._name = name
    self._U = unitary.flatten()
    self._target = target


  def apply(self, quantum_state):
    """
    Args:
      quantum_state (QuantumState): quantum state to which apply the quantum operator
    Return:
      updated (dict): didctionary with updated amplitudes
    """
    # Directly implement update rule on the amplitudes for a 2 qubits case.
    # NOTE: This approach is not scalable! Refine or use qiskit for more than 2 qubits
    a_00, a_01, a_10, a_11 = quantum_state.get_amplitudes()
    updated = dict()

    if self._target == 0:
      updated['00'] = self._U[0]*a_00 + self._U[1]*a_10
      updated['01'] = self._U[0]*a_01 + self._U[1]*a_11
      updated['10'] = self._U[2]*a_00 + self._U[3]*a_10
      updated['11'] = self._U[2]*a_01 + self._U[3]*a_11

    else:
      updated['00'] = self._U[0]*a_00 + self._U[1]*a_01
      updated['01'] = self._U[2]*a_00 + self._U[3]*a_01
      updated['10'] = self._U[0]*a_10 + self._U[1]*a_11
      updated['11'] = self._U[2]*a_10 + self._U[3]*a_11

    # Check if amplitudes still satisfy condition
    normalization = reduce(lambda a, b: a+b, map(lambda a: abs(a)**2, updated.values()))
    error = f"Error: sum of squared amplitudes must be = 1.\n Amplitudes: {list(updated.values())}, summing up to {normalization}"
    assert math.isclose(normalization, 1, rel_tol = 1e-2), error

    return updated


class CNOT(QuantumGate):
  def __init__(self, control):
    """
    Args:
      control (int): if 0, first qubit is the control, else second
    Return:
      result (QuantumState): quantum state with amplitudes modified
    """
    self._control = control
    super().__init__('cnot', np.array([[0, 1], [1, 0]]), 1-control)


  def apply(self, quantum_state):
    """
    Args:
      state (QuantumState): quantum state to which apply the quantum operator
    Return:
      result (QuantumState): quantum state with amplitudes modified
    """
    # Directly implement update rule on the amplitudes for a 2 qubits case.
    # NOTE: This approach is not scalable! Refine or use qiskit for more than 2 qubits
    a_00, a_01, a_10, a_11 = quantum_state.get_amplitudes()
    updated = dict()

    if self._control == 0: # Then control = 1st: if 1st qubit == 1, flip 2nd qubit.
      updated['00'] = a_00
      updated['01'] = a_01
      updated['10'] = self._U[0]*a_10 + self._U[1]*a_11
      updated['11'] = self._U[2]*a_10 + self._U[3]*a_11

    if self._control == 1: # Then control = 2nd: if 2nd qubit == 1, flip 1st qubit.
      updated['00'] = self._U[0]*a_00 + self._U[1]*a_10
      updated['01'] = self._U[0]*a_01 + self._U[1]*a_11
      updated['10'] = a_10
      updated['11'] = a_11

    # Check if amplitudes still satisfy condition
    normalization = reduce(lambda a, b: a+b, map(lambda a: abs(a)**2, updated.values()))
    error = f"Error: sum of squared amplitudes must be = 1.\n Amplitudes: {list(updated.values())}, summing up to {normalization}"
    assert math.isclose(normalization, 1, rel_tol = 1e-2), error

    return updated

# %% [markdown]
# ### Gates List

# %%
class Gates:
  def __init__(self):
    gates = dict()
    self._num_gates = 0

    # Useful
    targets = [0, 1]
    j = 1j # complex unit

    ########### CNOT ###########
    gates['CNOT'] = CNOT(control = 0)
    self._num_gates += 1

    ########### Rotations ###########
    angles_names = ['pi', '2pi/3', 'pi/2', 'pi/3', 'pi/4']
    angles_values = (math.pi / 2) * np.array([1, 2/3, 1/2, 1/3, 1/4])
    angles = {k:v for k,v in zip(angles_names, angles_values)}

    # Rx
    for name, theta in angles.items():
      for t in targets:
        key = 'Rx' + str(t) + '(' + name + ')'
        gates[key] = QuantumGate(key, np.array([[math.cos(theta), -j*math.sin(theta)],
                                                      [-j*math.sin(theta), math.cos(theta)]]), t)
        self._num_gates += 1

    # Ry
    for name, theta in angles.items():
      for t in targets:
        key = 'Ry' + str(t) + '(' + name + ')'
        gates[key] = QuantumGate(key, np.array([[math.cos(theta), -math.sin(theta)],
                                                      [math.sin(theta), math.cos(theta)]]), t)
        self._num_gates += 1

    # Rz
    for name, theta in angles.items():
      for t in targets:
        key = 'Rz' + str(t) + '(' + name + ')'
        gates[key] = QuantumGate(key, np.array([[cmath.exp(-j*theta), 0],
                                                      [0, cmath.exp(j*theta)]]), t)
        self._num_gates += 1

    # Hadamard
    # gates['H0'] = QuantumGate('Hadamard_0', math.sqrt(1/2)*np.array([[1, 1], [-1, 1]]), 0)
    # gates['H1'] = QuantumGate('Hadamard_1', math.sqrt(1/2)*np.array([[1, 1], [-1, 1]]), 1)

    self._keys = list(gates.keys())
    self._gates = list(gates.values())

  def num_gates(self):
    return self._num_gates

# %% [markdown]
# #### Google Gates

# %%
class GoogleGates:
  def __init__(self, keys = list()):
    PI = math.pi
    self._keys = keys
    self._gates = [
                  (cirq.CNOT, None),
                  (cirq.rx(PI), cirq.I),
                  (cirq.I, cirq.rx(PI)),
                  (cirq.rx(2*PI/3), cirq.I),
                  (cirq.I, cirq.rx(2*PI/3)),
                  (cirq.rx(PI/2), cirq.I),
                  (cirq.I, cirq.rx(PI/2)),
                  (cirq.rx(PI/3), cirq.I),
                  (cirq.I, cirq.rx(PI/3)),
                  (cirq.rx(PI/4), cirq.I),
                  (cirq.I, cirq.rx(PI/4)),
                  (cirq.ry(PI), cirq.I),
                  (cirq.I, cirq.ry(PI)),
                  (cirq.ry(2*PI/3), cirq.I),
                  (cirq.I, cirq.ry(2*PI/3)),
                  (cirq.ry(PI/2), cirq.I),
                  (cirq.I, cirq.ry(PI/2)),
                  (cirq.ry(PI/3), cirq.I),
                  (cirq.I, cirq.ry(PI/3)),
                  (cirq.ry(PI/4), cirq.I),
                  (cirq.I, cirq.ry(PI/4)),
                  (cirq.rz(PI), cirq.I),
                  (cirq.I, cirq.rz(PI)),
                  (cirq.rz(2*PI/3), cirq.I),
                  (cirq.I, cirq.rz(2*PI/3)),
                  (cirq.rz(PI/2), cirq.I),
                  (cirq.I, cirq.rz(PI/2)),
                  (cirq.rz(PI/3), cirq.I),
                  (cirq.I, cirq.rz(PI/3)),
                  (cirq.rz(PI/4), cirq.I),
                  (cirq.I, cirq.rz(PI/4)),
                  # (cirq.H, cirq.I),
                  # (cirq.I, cirq.H),
    ]


  def num_gates(self):
    return len(self._gates)

# %% [markdown]
# # RL Setup

# %% [markdown]
# ## Environment

# %%
class Environment:
  def __init__(self, initial_state, target_state,
               tolerance, negative_reward, positive_reward, discount = 0):
    """
    Args:
      initial_state (QuantumState): initial state of the system
      target_state (QuantumState): target state of the system
      tolerance (float): tolerance in terms of fidelity score
    """
    self._initial_state = initial_state
    self._target_state = target_state

    self._tolerance = tolerance # tolerance in terms of fidelity between

    self._quantum_gates, self._keys, self._num_gates = self.gates_set()

    self._terminal_fidelity = 0 # used to retrieve the info at the end of an episode
    self._terminal_state = None # used to retrieve the info at the end of an episode

    self._negative_reward = negative_reward
    self._positive_reward = positive_reward
    self._discount = discount

    # Used to initialize Environment instance from scratch.
    self.reset()


  def gates_set(self):
    """
    Returns:
      gates._gates (List[QuantumGate]): return the list with available QuantumGate objects
      gates._keys (Dict[String: Int]): dictionary mapping a gate to its action index
      gates.num_gates() (int): number of available gates (actions)
    """
    gates = Gates()
    return gates._gates, gates._keys, gates.num_gates()


  def step(self, action):
    """
    Given a gate, apply it to self._state.
    Set the reward, resulting state and discount.
    Return these values, along with the information if the terminal state has been reached
    Args:
      action (int): action index to select a QuantumGate

    Return:
      reward, discount, next_state features, terminal
    """
    # Get and apply action. next_state is a QuantumState
    gate = self._quantum_gates[action]
    next_state = self._state.apply_gate(gate)

    # Compare new state and target
    fidelity = next_state.fidelity_score(self._target_state)

    # Assign reward based on state and fidelity
    terminal = self.is_terminal(fidelity)

    # Terminal state
    if terminal:
      reward = self._positive_reward
      discount = 0.
      self._terminal_fidelity = fidelity
      self._terminal_state = next_state
      self.reset()
    else:
      reward = self._negative_reward
      discount = self._discount
      self._state = next_state

    # Return the features, not the state itself
    return reward, discount, self.get_obs(), terminal


  def is_terminal(self, fidelity):
    """
    Check if, by a level of self.tolerance, state is terminal
    """
    if fidelity > (1 - self._tolerance):
      return True

    return False


  def get_obs(self):
    return self._state.get_features()


  def reset(self):
    self._state = self._initial_state

# %% [markdown]
# ## Agent

# %%
class ReplayBuffer(object):

  def __init__(self):
    self.buffer = []

  def append_transition(self, transition):
    """
    Args:
      transition (tuple): (state, action, reward, discount, next state)
    """
    self.buffer.append(transition)

  def sample_transition(self):
    return random.choice(self.buffer)

  def clear(self):
    self.buffer = []

# %%
# Least Square TD Agent: action value function approximation
# implemented with gradient descent.
class LSTDAgent:
  def __init__(self, number_of_actions, number_of_features,
      initial_state, step_size, num_offline_updates, eps = 1.):
    """
    Args:
      initial_state: it is a feature vector!
    """
    self._number_of_actions = number_of_actions
    self._number_of_features = number_of_features
    self._W = np.zeros((number_of_actions, number_of_features), dtype = np.float16)

    self._step_size = step_size
    self._initial_state = initial_state

    self._num_offline_updates = num_offline_updates
    self._replay_buffer = ReplayBuffer() # supervised dataset
    self._step = 0

    self._eps = eps # By default, fully random behavioural policy

    # St self._state to initial state and pick an action randomly
    self.reset(True)


  def behaviour_policy(self, state = None):
    greedy = np.random.choice([True, False], p=[1-self._eps, self._eps])
    if greedy:
      return np.argmax(self.q(state))
    return random.choice(range(self._number_of_actions))


  def q(self, state):
    """
    Args:
      state (list): list of the amplitudes := features of the state
    """
    return np.matmul(self._W, state)


  def step(self, reward, discount, next_state):
    """
    Args:
      next_state (list): list of the amplitude: these are already features, not a QuantumState instance
      terminal (boolean): if next_state is the terminal state
    """
    s = self._state
    a = self._action
    r = reward
    next_s = next_state
    g = discount

    # print(f"State: {s}")
    # print(f"Next State: {next_s}")
    # print()
    self._W[a] += self._step_size * (r + g * np.max(self.q(next_s)) - self.q(s)[a]) * s

    # Experience replay
    self._replay_buffer.append_transition((s, a, r, g, next_s))
    for _ in range(self._num_offline_updates):
      s, a, r, g, next_s = self._replay_buffer.sample_transition()
      self._W[a] += self._step_size * (r + g * np.max(self.q(next_s)) - self.q(s)[a]) * s

    next_a = self.behaviour_policy(next_s)
    self._action = next_a
    self._state = next_s
    self._step += 1

    return next_a


  def inference(self, reward, discount, next_state):
    s = self._state
    a = self._action
    r = reward
    next_s = next_state
    g = discount

    next_a = np.argmax(self.q(next_s))
    self._action = next_a
    self._state = next_s

    return next_a


  def reset(self, random = False, W = None):
    self._state = self._initial_state
    self._action = self.behaviour_policy(self._state)


    self._replay_buffer.clear()

# %% [markdown]
# # Helper Functions

# %%
def compare_circuits(circuit_gates, final_state, target_state, path = None):
  """
  Compare results obtained by google gates vs my custom gates implementation
  Args:
    circuit_gates (List[int]): indices of the gates in the circuit defined by the agent
    final_state (QuantumState): terminal state reached by the agent
    target_state (QuantumState): target state of TD agent
  """
  my_gates = Gates()
  google_gates = GoogleGates(my_gates._keys)

  # Google initialization
  q0 = cirq.NamedQubit('q0')
  q1 = cirq.NamedQubit('q1')
  circuit = cirq.Circuit()
  def basic_circuit(u0, u1):
    if (u1 is not None):
      yield u0(q0), u1(q1)
    else:
      yield u0(q0, q1)

  # Create the circuit with both Google API and my implementation
  q = QuantumState(np.array([1, 0, 0, 0]))
  for idx in circuit_gates:
    q = q.apply_gate(my_gates._gates[idx])
    circuit.append(basic_circuit(*google_gates._gates[idx]))

  # Simulate Google circuit - oracle
  simulator = Simulator()
  google_result = simulator.simulate(circuit, qubit_order=[q0, q1])

  # Check coherence between approximate terminal states
  assert np.all(np.around(q.get_amplitudes(), 3) == np.around(final_state.get_amplitudes(), 3)),\
   f"Unexpected terminal state: got {np.around(q.get_amplitudes(), 3)} rather than {np.around(final_state.get_amplitudes(), 3)}"

  # Check coherence between Google result and mine
  assert np.allclose(q.get_amplitudes(), np.array(google_result.final_state_vector), atol = 1e-8),\
   f"Unexpected terminal state: got {np.around(q.get_amplitudes(), 3)} rather than {np.around(google_result.final_state_vector, 3)}"

  print(f"Approximate state: {np.around(final_state.get_amplitudes(), 3)}")
  print(f"Target state: {np.around(target_state.get_amplitudes(), 3)}")
  print(f"Fidelity score: {target_state.fidelity_score(final_state)}. Number of gates: {len(circuit_gates)}")

  print("")
  print(circuit)

  if path is not None:
    logs(final_state, target_state, circuit_gates, circuit, path)

# %%
def get_quantum_state(tolerance, seed, i):
  """
  Get a feasible set of amplitudes of a quantum state,
  by applying a random number of random gates to the initial state |00>

  Return:
    amplitudes (np.array): list of new state amplitudes
  """
  random.seed(seed + i)
  np.random.seed(seed + i)

  gates = GoogleGates()

  # Circuit initialization
  q0 = cirq.NamedQubit('q0')
  q1 = cirq.NamedQubit('q1')
  circuit = cirq.Circuit()
  def basic_circuit(u0, u1):
    if (u1 is not None):
      yield u0(q0), u1(q1)
    else:
      yield u0(q0, q1)

  is_next = True
  while is_next:
    idx = random.choice(range(gates.num_gates()))
    circuit.append(basic_circuit(*gates._gates[idx]))
    is_next = np.random.choice([True, False], p=[0.9, 0.1])

  simulator = Simulator()
  result = simulator.simulate(circuit, qubit_order=[q0, q1])

  amplitudes = result.final_state_vector

  # Check correctness of the new state
  error = "Error: sum of squared amplitudes must be = 1"
  val = reduce(lambda a, b: a+b, map(lambda a: abs(a)**2, amplitudes))
  assert math.isclose(val, 1, rel_tol = 1e-2), error + f" instead is {val}"

  # If I am equal to the initial state
  if QuantumState(amplitudes).fidelity_score(QuantumState(np.array([1, 0, 0, 0]))) > (1-tolerance):
    get_quantum_state(tolerance, seed, i*100)

  return amplitudes

# %%
def logs(final_state, target_state, circuit_gates, circuit, path):
  """
  extra: any extra information I want to include in the logging
  """
  with open(path, 'a+') as f:
    f.write(f"Approximate state: {np.around(final_state.get_amplitudes(), 3)}\n")
    f.write(f"Target state: {np.around(target_state.get_amplitudes(), 3)}\n")
    f.write(f"Fidelity score: {target_state.fidelity_score(final_state)}. Number of gates: {len(circuit_gates)}\n")
    f.write(f"Gates List: ")
    f.write(f"{circuit_gates}\n")
    f.write(f"{circuit}\n\n")

# %% [markdown]
# # Experiment Facade

# %%
# Facade class to run experiment
class Experiment:
  def __init__(self, start_state, target_state, tolerance, number_of_episodes,
               step_size, num_offline_updates, negative_reward, positive_reward,
               discount, eps = 1.0):

    self._env = Environment(QuantumState(start_state), QuantumState(target_state),
                            tolerance, negative_reward, positive_reward, discount)

    number_of_actions = len(self._env._keys)
    initial_features = self._env.get_obs()

    self._agent = LSTDAgent(number_of_actions, len(initial_features), initial_features,
                            step_size, num_offline_updates, eps)

    self._number_of_episodes = number_of_episodes


  def run_experiment(self):
    """
    Run episodes, gathering statistics and updating user on console.
    """
    min_steps = -1
    min_gates = []
    min_terminal_state = None
    for episode in range(self._number_of_episodes):
        self.run_episode()
        gates, terminal_state = self.run_inference(episode)
        if min_steps == -1 or len(gates) < min_steps:
            min_steps = len(gates)
            min_gates = gates
            min_terminal_state = terminal_state

    return min_gates, min_terminal_state


  def run_episode(self):
    """
    Run a single episode.
    At the beginning of an episode we must guarantee
    - initial state in the environment
    - initial state in the agent
    """
    terminal = False
    action = self._agent._action
    while not terminal:
      reward, discount, next_s, terminal = self._env.step(action)
      action = self._agent.step(reward, discount, next_s)

    # Add a reset step below, to take first action
    self._agent.reset()


  def run_inference(self, episode):
    """
    Run an episode using the optimal policy learned
    """
    terminal = False
    action = self._agent._action
    gates = []
    while not terminal and len(gates) <= 1000:
      gates.append(action)
      reward, discount, next_s, terminal = self._env.step(action)
      action = self._agent.inference(reward, discount, next_s)

    if not terminal:
      return gates, self._env._state

    max_gates = 20
    if len(gates) < max_gates:
      print(f"Episode {episode}: inference completed in {len(gates)} steps. Fidelity score: {self._env._terminal_fidelity}")

    return gates, self._env._terminal_state


  def q_values(self):
    """
    The function should plot, in a [0, 1] complex plane, the value function
    on the z axis, for each of the 4 value of amplitude.
    In order to get reasonable values and understand the effect of the amplitude
    under analysis on the overall q_values, the remaining amplitudes values will
    be set to the target amplitudes.
    """
    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

    state = self._env._target_state
    features = state.get_features()
    x = np.linspace(0, 1, num=100)
    y = np.linspace(0, 1, num=100)
    grid = np.meshgrid
    q = []
    for i in x:
      row = []
      for k in y:
        features[0] = i
        features[0] = k
        row.append(self._agent.q(features))

      q.append(row)

    q = np.array(q)
    surf = ax.plot_surface(x, y, np.squeeze(q[:, :, 0]), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

    # Add a color bar which maps values to colors.
    fig.colorbar(surf, shrink=0.5, aspect=5)

    plt.show()

# %% [markdown]
# # Experiment

# %% [markdown]
# ## Random Target States

# %%
TOLERANCE = 0.15
TRAINING_EPISODES = 100
NUM_OFFLINE_UPDATES = 0 # WAY WORSE IF != 0

STEP_SIZE = 0.0001
NEG_REWARD = -1.
POS_REWARD = 100.
DISCOUNT = 0.
EPS = 1
SEED = 100
NUM_EXPERIMENTS = 5
PATH = "logs.txt"

# %%
with open(PATH, "w+") as f:
  f.write(f"TOLERANCE: {TOLERANCE}\n")
  f.write(f"TRAINING_EPISODES: {TRAINING_EPISODES}\n")
  f.write(f"STEP_SIZE: {STEP_SIZE}\n")
  f.write(f"NUM_OFFLINE_UPDATES: {NUM_OFFLINE_UPDATES}\n")
  f.write(f"SEED: {SEED}\n")
  f.write(f"NUM_EXPERIMENTS: {NUM_EXPERIMENTS}\n\n")

# %%
for i in range(NUM_EXPERIMENTS):
  start = [1, 0, 0, 0]
  target = get_quantum_state(TOLERANCE, SEED, i)

  print(f"Experiment {i}")

  experiment = Experiment(start, target, TOLERANCE, TRAINING_EPISODES, STEP_SIZE,
                          NUM_OFFLINE_UPDATES, NEG_REWARD, POS_REWARD,
                          DISCOUNT, EPS)
  circuit_gates, terminal_state = experiment.run_experiment()
  target_state = QuantumState(target)
  compare_circuits(circuit_gates, terminal_state, target_state, PATH)
  print()

  sns.heatmap(experiment._agent._W)
  plt.show()
  print()
  print()
# Out:
# Experiment 0
# Episode 14: inference completed in 4 steps. Fidelity score: 0.957977813048363
# Episode 30: inference completed in 3 steps. Fidelity score: 0.957977813048363
# Episode 33: inference completed in 3 steps. Fidelity score: 0.9432144329682495
# Episode 54: inference completed in 3 steps. Fidelity score: 0.8888670861801197
# Episode 56: inference completed in 9 steps. Fidelity score: 0.900187711051905
# Episode 58: inference completed in 13 steps. Fidelity score: 0.9092912647561376
# Episode 64: inference completed in 3 steps. Fidelity score: 0.957977813048363
# Episode 65: inference completed in 4 steps. Fidelity score: 0.9579778130483628
# Episode 69: inference completed in 9 steps. Fidelity score: 0.8522145003507002
# Episode 72: inference completed in 5 steps. Fidelity score: 0.9579778130483626
# Episode 83: inference completed in 3 steps. Fidelity score: 0.8888670861801197
# Episode 89: inference completed in 3 steps. Fidelity score: 0.8888670861801197
# Episode 92: inference completed in 3 steps. Fidelity score: 0.8888670861801197
# Episode 93: inference completed in 3 steps. Fidelity score: 0.957977813048363
# Episode 95: inference completed in 3 steps. Fidelity score: 0.957977813048363
# Episode 98: inference completed in 3 steps. Fidelity score: 0.9579778130483628
# Episode 99: inference completed in 3 steps. Fidelity score: 0.957977813048363
# Approximate state: [0.   +0.j    0.   -0.j    0.707+0.j    0.   -0.707j]
# Target state: [ 0.061-0.079j -0.076-0.032j -0.319+0.697j  0.62 +0.107j]
# Fidelity score: 0.957977813048363. Number of gates: 3
#
# q0: ───I──────────Ry(0.5π)───Ry(0.5π)───
#
# q1: ───Rx(0.5π)───I──────────I──────────
# Experiment 1
# Episode 6: inference completed in 16 steps. Fidelity score: 0.9248322997880165
# Episode 18: inference completed in 13 steps. Fidelity score: 0.9179153291195561
# Episode 20: inference completed in 10 steps. Fidelity score: 0.873765302766302
# Episode 22: inference completed in 4 steps. Fidelity score: 0.8778897077692432
# Episode 24: inference completed in 19 steps. Fidelity score: 0.928110944528508
# Episode 30: inference completed in 3 steps. Fidelity score: 0.8928560339910102
# Episode 38: inference completed in 18 steps. Fidelity score: 0.8728522796507207
# Episode 39: inference completed in 5 steps. Fidelity score: 0.9112693046122099
# Episode 43: inference completed in 8 steps. Fidelity score: 0.9318487814302222
# Episode 50: inference completed in 6 steps. Fidelity score: 0.8780640503731673
# Episode 51: inference completed in 17 steps. Fidelity score: 0.8554093717475127
# Episode 64: inference completed in 17 steps. Fidelity score: 0.8656978159989165
# Episode 66: inference completed in 19 steps. Fidelity score: 0.8823735496246882
# Episode 70: inference completed in 19 steps. Fidelity score: 0.8568165539962124
# Episode 71: inference completed in 6 steps. Fidelity score: 0.877889707769243
# Episode 72: inference completed in 15 steps. Fidelity score: 0.8933346421122175
# Episode 73: inference completed in 13 steps. Fidelity score: 0.9315518351536578
# Episode 79: inference completed in 7 steps. Fidelity score: 0.8925139574372836
# Episode 80: inference completed in 10 steps. Fidelity score: 0.8780640503731673
# Episode 81: inference completed in 7 steps. Fidelity score: 0.8925139574372836
# Episode 88: inference completed in 11 steps. Fidelity score: 0.9629494234848626
# Episode 95: inference completed in 11 steps. Fidelity score: 0.8605138244470472
# Episode 97: inference completed in 6 steps. Fidelity score: 0.9220046996924796
# Episode 99: inference completed in 18 steps. Fidelity score: 0.8943413626870482
# Approximate state: [-0.75   0.433 -0.433  0.25 ]
# Target state: [-0.354-0.586j  0.01 +0.525j -0.039-0.398j -0.127+0.28j ]
# Fidelity score: 0.8928560339910102. Number of gates: 3
#
# q0: ───Ry(0.333π)───I────────────I───────
#
# q1: ───I────────────Ry(0.667π)───Ry(π)───
# Experiment 2
# Episode 17: inference completed in 17 steps. Fidelity score: 0.9529199675514529
# Episode 22: inference completed in 12 steps. Fidelity score: 0.8647817120000063
# Episode 23: inference completed in 13 steps. Fidelity score: 0.8696327253870687
# Episode 28: inference completed in 14 steps. Fidelity score: 0.8933205385464161
# Episode 30: inference completed in 15 steps. Fidelity score: 0.8990203348935352
# Episode 33: inference completed in 5 steps. Fidelity score: 0.8647817120000068
# Episode 37: inference completed in 6 steps. Fidelity score: 0.8647817120000068
# Episode 38: inference completed in 2 steps. Fidelity score: 0.8568451345910139
# Episode 40: inference completed in 13 steps. Fidelity score: 0.9026955453178557
# Episode 43: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 44: inference completed in 3 steps. Fidelity score: 0.8647817120000063
# Episode 45: inference completed in 6 steps. Fidelity score: 0.9125274113523718
# Episode 46: inference completed in 9 steps. Fidelity score: 0.9425799249992272
# Episode 47: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 48: inference completed in 13 steps. Fidelity score: 0.8839464386111882
# Episode 49: inference completed in 16 steps. Fidelity score: 0.8921340426081326
# Episode 50: inference completed in 6 steps. Fidelity score: 0.9125274113523718
# Episode 51: inference completed in 3 steps. Fidelity score: 0.8568451345910139
# Episode 52: inference completed in 9 steps. Fidelity score: 0.861651629428584
# Episode 57: inference completed in 3 steps. Fidelity score: 0.8647817120000065
# Episode 58: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 61: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 63: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 64: inference completed in 3 steps. Fidelity score: 0.8647817120000065
# Episode 67: inference completed in 3 steps. Fidelity score: 0.8647817120000065
# Episode 70: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 72: inference completed in 3 steps. Fidelity score: 0.8647817120000065
# Episode 73: inference completed in 2 steps. Fidelity score: 0.8616516294285838
# Episode 74: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 76: inference completed in 2 steps. Fidelity score: 0.8647817120000068
# Episode 77: inference completed in 3 steps. Fidelity score: 0.8647817120000065
# Episode 78: inference completed in 17 steps. Fidelity score: 0.9605166591595298
# Episode 79: inference completed in 3 steps. Fidelity score: 0.8647817120000065
# Episode 80: inference completed in 3 steps. Fidelity score: 0.8647817120000063
# Episode 81: inference completed in 12 steps. Fidelity score: 0.8774452448595035
# Episode 82: inference completed in 12 steps. Fidelity score: 0.8774452448595035
# Episode 85: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 88: inference completed in 3 steps. Fidelity score: 0.8568451345910139
# Episode 91: inference completed in 3 steps. Fidelity score: 0.8568451345910139
# Episode 93: inference completed in 3 steps. Fidelity score: 0.8647817120000068
# Episode 97: inference completed in 3 steps. Fidelity score: 0.8568451345910139
# Approximate state: [ 0.5+0.j   0. -0.5j  0. -0.5j -0.5+0.j ]
# Target state: [ 0.479+0.037j -0.18 -0.326j -0.188-0.599j -0.307+0.377j]
# Fidelity score: 0.8568451345910139. Number of gates: 2
#
# q0: ───I──────────Rx(0.5π)───
#
# q1: ───Rx(0.5π)───I──────────
# Experiment 3
# Episode 13: inference completed in 5 steps. Fidelity score: 0.9330127289129974
# Episode 16: inference completed in 1 steps. Fidelity score: 0.9171169064088983
# Episode 18: inference completed in 8 steps. Fidelity score: 0.9497595414476053
# Episode 19: inference completed in 8 steps. Fidelity score: 0.9330127289129969
# Episode 20: inference completed in 7 steps. Fidelity score: 0.8535533929718826
# Episode 22: inference completed in 1 steps. Fidelity score: 0.9330127289129974
# Episode 23: inference completed in 7 steps. Fidelity score: 0.8535533929718822
# Episode 24: inference completed in 6 steps. Fidelity score: 0.9330127289129971
# Episode 25: inference completed in 14 steps. Fidelity score: 0.8750000210857117
# Episode 26: inference completed in 7 steps. Fidelity score: 0.8535533929718826
# Episode 27: inference completed in 6 steps. Fidelity score: 0.9330127289129971
# Episode 28: inference completed in 9 steps. Fidelity score: 0.8945745757055054
# Episode 29: inference completed in 11 steps. Fidelity score: 0.8535533929718819
# Episode 31: inference completed in 4 steps. Fidelity score: 0.8535534129315353
# Episode 32: inference completed in 10 steps. Fidelity score: 0.9171169064088976
# Episode 34: inference completed in 3 steps. Fidelity score: 0.9330127289129974
# Episode 35: inference completed in 1 steps. Fidelity score: 0.9171169064088983
# Episode 37: inference completed in 13 steps. Fidelity score: 0.9662160992212361
# Episode 41: inference completed in 3 steps. Fidelity score: 0.9330127289129974
# Episode 50: inference completed in 8 steps. Fidelity score: 0.9171169064088983
# Episode 55: inference completed in 10 steps. Fidelity score: 0.8886047164993653
# Episode 58: inference completed in 12 steps. Fidelity score: 0.9330127289129967
# Episode 59: inference completed in 11 steps. Fidelity score: 0.9330127289129974
# Episode 60: inference completed in 7 steps. Fidelity score: 0.9171169064088981
# Episode 62: inference completed in 12 steps. Fidelity score: 0.9418091539510909
# Episode 63: inference completed in 7 steps. Fidelity score: 0.9171169064088979
# Episode 64: inference completed in 5 steps. Fidelity score: 0.8535533929718824
# Episode 66: inference completed in 1 steps. Fidelity score: 0.9330127289129974
# Episode 69: inference completed in 14 steps. Fidelity score: 0.8535533929718816
# Episode 70: inference completed in 7 steps. Fidelity score: 0.8788436354130018
# Episode 72: inference completed in 8 steps. Fidelity score: 0.8567465395254019
# Episode 73: inference completed in 7 steps. Fidelity score: 0.8788436354130018
# Episode 74: inference completed in 11 steps. Fidelity score: 0.9171169136176051
# Episode 75: inference completed in 8 steps. Fidelity score: 0.8567465395254019
# Episode 76: inference completed in 10 steps. Fidelity score: 0.9171169136176046
# Episode 77: inference completed in 2 steps. Fidelity score: 0.9171169064088981
# Episode 79: inference completed in 2 steps. Fidelity score: 0.9171169064088981
# Episode 81: inference completed in 12 steps. Fidelity score: 0.868808590236932
# Episode 84: inference completed in 8 steps. Fidelity score: 0.9171168802379278
# Episode 85: inference completed in 2 steps. Fidelity score: 0.9171169064088983
# Episode 86: inference completed in 6 steps. Fidelity score: 0.8705127256279996
# Episode 87: inference completed in 2 steps. Fidelity score: 0.9171169064088981
# Episode 88: inference completed in 2 steps. Fidelity score: 0.9171169064088983
# Episode 89: inference completed in 2 steps. Fidelity score: 0.9171169064088981
# Episode 90: inference completed in 2 steps. Fidelity score: 0.9171169064088981
# Episode 91: inference completed in 2 steps. Fidelity score: 0.9171169064088983
# Episode 96: inference completed in 2 steps. Fidelity score: 0.9171169064088983
# Episode 97: inference completed in 1 steps. Fidelity score: 0.9171169064088983
# Episode 98: inference completed in 10 steps. Fidelity score: 0.9171169064088981
# Approximate state: [0.866 0.    0.5   0.   ]
# Target state: [-0.446-0.773j  0.207-0.12j  -0.185-0.32j   0.086-0.05j ]
# Fidelity score: 0.9171169064088983. Number of gates: 1
#
# q0: ───Ry(0.333π)───
#
# q1: ───I────────────
# Experiment 4
# Episode 16: inference completed in 15 steps. Fidelity score: 0.8746994285110112
# Episode 23: inference completed in 10 steps. Fidelity score: 0.8695994609985409
# Episode 66: inference completed in 8 steps. Fidelity score: 0.8746994250442103
# Episode 70: inference completed in 7 steps. Fidelity score: 0.8705127203614731
# Episode 73: inference completed in 6 steps. Fidelity score: 0.9171169032166708
# Episode 74: inference completed in 6 steps. Fidelity score: 0.8705127203614725
# Episode 79: inference completed in 6 steps. Fidelity score: 0.9171169032166708
# Episode 82: inference completed in 7 steps. Fidelity score: 0.9182581687402418
# Episode 87: inference completed in 5 steps. Fidelity score: 0.8567465343407455
# Episode 90: inference completed in 13 steps. Fidelity score: 0.8752576098710504
# Episode 96: inference completed in 9 steps. Fidelity score: 0.9330127150991568
# Approximate state: [-0.43 +0.j     0.561+0.j     0.   +0.43j   0.   -0.561j]
# Target state: [ 0.486+0.373j -0.607-0.08j   0.215-0.28j  -0.046+0.351j]
# Fidelity score: 0.8567465343407455. Number of gates: 5
#
# q0: ───I────────────I───────────I───────────Rx(0.5π)───I───────────
#
# q1: ───Ry(0.667π)───Ry(0.25π)───Ry(0.25π)───I──────────Ry(0.25π)───

# %%
files.download(PATH)

# %% [markdown]
# ## Bell Target States

# %%
# Bell states amplitudes
bell_amplitudes = np.array([[1/math.sqrt(2), 0, 0, 1/math.sqrt(2)], # |00> + |11>
                            [0, 1/math.sqrt(2), 1/math.sqrt(2), 0], # |01> + |10>
                            [1/math.sqrt(2), 0, 0, -1/math.sqrt(2)], # |00> - |11>
                            [0, 1/math.sqrt(2), -1/math.sqrt(2), 0]]) # |01> - |10>
bell_dict = {
    '|00> + |11>' : bell_amplitudes[0],
    '|01> + |10>' : bell_amplitudes[1],
    '|00> - |11>' : bell_amplitudes[2],
    '|01> - |10>' : bell_amplitudes[3],
}

# %% [markdown]
# ### Parameter tuning

# %%
TOLERANCE = 0.15
TRAINING_EPISODES = 100
NUM_OFFLINE_UPDATES = 0 # WAY WORSE IF != 0

# %%
params = {
    'step_size': [0.0001, 0.0005],
    'positive_reward': [1, 50., 100.],
    'negative_reward': [0, -5.],
    'discount': [0.5, 0.75, 0.9]
}

param_grid = ParameterGrid(params)

# %%
# %%time
def experiment_logs(logs, circuit_gates, final_state, target_state, params, rep):
  logs[rep]['fidelity'].append(target_state.fidelity_score(final_state))
  logs[rep]['num_gates'].append(len(circuit_gates))
  logs[rep]['params'].append(params)

gridsearch_logs = {key:{'params': [], 'fidelity':[], 'num_gates':[]} for key in bell_dict.keys()}

for params in  param_grid:
  print(params)
  step_size = params['step_size']
  negative_reward = params['negative_reward']
  positive_reward = params['positive_reward']
  discount = params['discount']
  for rep, bell_state in bell_dict.items():
    print(rep)
    start = [1, 0, 0, 0]
    target = bell_state

    experiment = Experiment(start, target, TOLERANCE, TRAINING_EPISODES, step_size, NUM_OFFLINE_UPDATES,
                            negative_reward, positive_reward, discount)

    circuit_gates, terminal_state = experiment.run_experiment()

    experiment_logs(gridsearch_logs, circuit_gates, terminal_state, QuantumState(target), params, rep)
    print()
  print()

gridsearch_df = pd.DataFrame(gridsearch_logs)
# Out:
# {'discount': 0.5, 'negative_reward': 0, 'positive_reward': 1, 'step_size': 0.0001}
# |00> + |11>
# Episode 5: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 7: inference completed in 19 steps. Fidelity score: 0.8695994598700574
# Episode 9: inference completed in 10 steps. Fidelity score: 0.9999999999999996
# Episode 12: inference completed in 6 steps. Fidelity score: 0.9999999999999998
# Episode 13: inference completed in 8 steps. Fidelity score: 0.9999999999999996
# Episode 16: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 24: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 26: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 29: inference completed in 18 steps. Fidelity score: 0.8553184540119775
# Episode 62: inference completed in 9 steps. Fidelity score: 0.9829629131445337
# Episode 64: inference completed in 12 steps. Fidelity score: 0.8705127018922193
# Episode 77: inference completed in 19 steps. Fidelity score: 0.8567465193097622
# Episode 79: inference completed in 19 steps. Fidelity score: 0.8567465193097622
# Episode 91: inference completed in 7 steps. Fidelity score: 0.8749999999999998
# Episode 99: inference completed in 16 steps. Fidelity score: 0.9999999999999998
#
# |01> + |10>
# Episode 47: inference completed in 13 steps. Fidelity score: 0.9330127018922192
# Episode 69: inference completed in 18 steps. Fidelity score: 0.8705127018922191
# Episode 74: inference completed in 17 steps. Fidelity score: 0.8705127018922184
# Episode 76: inference completed in 18 steps. Fidelity score: 0.8705127018922191
# Episode 77: inference completed in 13 steps. Fidelity score: 0.8705127018922195
#
# |00> - |11>
# Episode 5: inference completed in 5 steps. Fidelity score: 0.875
# Episode 10: inference completed in 5 steps. Fidelity score: 0.9999999999999993
# Episode 12: inference completed in 8 steps. Fidelity score: 0.853553390593274
# Episode 14: inference completed in 16 steps. Fidelity score: 0.9330127018922194
# Episode 16: inference completed in 6 steps. Fidelity score: 0.9330127018922194
#
# |01> - |10>
# Episode 83: inference completed in 8 steps. Fidelity score: 0.8535533905932733
#
#
# {'discount': 0.5, 'negative_reward': 0, 'positive_reward': 1, 'step_size': 0.0005}
# |00> + |11>
# Episode 4: inference completed in 11 steps. Fidelity score: 0.8998196448143738
# Episode 7: inference completed in 6 steps. Fidelity score: 0.8705127018922191
#
# |01> + |10>
# Episode 8: inference completed in 18 steps. Fidelity score: 0.9506105325067195
# Episode 21: inference completed in 6 steps. Fidelity score: 0.9999999999999998
# Episode 27: inference completed in 6 steps. Fidelity score: 0.9999999999999998
# Episode 29: inference completed in 12 steps. Fidelity score: 0.9999999999999996
#
# |00> - |11>
# Episode 63: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 65: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 73: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 75: inference completed in 5 steps. Fidelity score: 0.9999999999999998
#
# |01> - |10>
#
#
# {'discount': 0.5, 'negative_reward': 0, 'positive_reward': 50.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 36: inference completed in 11 steps. Fidelity score: 0.9131478740674828
# Episode 47: inference completed in 7 steps. Fidelity score: 0.9040063509461095
# Episode 52: inference completed in 6 steps. Fidelity score: 0.875
#
# |01> + |10>
# Episode 53: inference completed in 7 steps. Fidelity score: 0.9999999999999998
# Episode 55: inference completed in 5 steps. Fidelity score: 1.0
# Episode 59: inference completed in 5 steps. Fidelity score: 0.9330127018922192
#
# |00> - |11>
# Episode 38: inference completed in 14 steps. Fidelity score: 0.9171168834528286
# Episode 96: inference completed in 12 steps. Fidelity score: 0.9330127018922194
#
# |01> - |10>
# Episode 48: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 66: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 67: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 68: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 77: inference completed in 6 steps. Fidelity score: 0.8535533905932735
# Episode 78: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 79: inference completed in 6 steps. Fidelity score: 0.8535533905932735
# Episode 80: inference completed in 6 steps. Fidelity score: 0.933012701892219
# Episode 81: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 83: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 86: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 93: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 98: inference completed in 18 steps. Fidelity score: 0.933012701892219
#
#
# {'discount': 0.5, 'negative_reward': 0, 'positive_reward': 50.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 17: inference completed in 4 steps. Fidelity score: 0.933012701892219
# Episode 18: inference completed in 10 steps. Fidelity score: 0.9330127018922194
# Episode 19: inference completed in 5 steps. Fidelity score: 0.8535533905932735
# Episode 20: inference completed in 4 steps. Fidelity score: 0.8535533905932737
# Episode 21: inference completed in 10 steps. Fidelity score: 0.933012701892219
# Episode 22: inference completed in 9 steps. Fidelity score: 0.9330127018922194
# Episode 24: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 48: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 55: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 64: inference completed in 15 steps. Fidelity score: 0.933012701892219
# Episode 70: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 72: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 79: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 80: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 91: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 92: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 97: inference completed in 2 steps. Fidelity score: 0.9330127018922192
#
# |01> + |10>
# Episode 11: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 27: inference completed in 5 steps. Fidelity score: 0.8535533905932737
# Episode 33: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 37: inference completed in 6 steps. Fidelity score: 0.8535533905932737
# Episode 38: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 40: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 43: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 44: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 50: inference completed in 7 steps. Fidelity score: 0.8535533905932735
# Episode 51: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 52: inference completed in 7 steps. Fidelity score: 0.8535533905932735
# Episode 56: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 81: inference completed in 8 steps. Fidelity score: 0.875
# Episode 93: inference completed in 10 steps. Fidelity score: 0.9497595264191642
#
# |00> - |11>
# Episode 27: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 47: inference completed in 10 steps. Fidelity score: 0.9330127018922192
# Episode 60: inference completed in 10 steps. Fidelity score: 0.8535533905932735
#
# |01> - |10>
# Episode 66: inference completed in 11 steps. Fidelity score: 0.9330127018922194
# Episode 68: inference completed in 14 steps. Fidelity score: 0.8861377018922191
#
#
# {'discount': 0.5, 'negative_reward': 0, 'positive_reward': 100.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 24: inference completed in 16 steps. Fidelity score: 0.8535533905932735
# Episode 44: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 45: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 52: inference completed in 4 steps. Fidelity score: 0.8535533905932737
# Episode 56: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 58: inference completed in 12 steps. Fidelity score: 0.9330127018922187
# Episode 59: inference completed in 12 steps. Fidelity score: 0.875
# Episode 61: inference completed in 12 steps. Fidelity score: 0.9330127018922187
# Episode 62: inference completed in 3 steps. Fidelity score: 0.875
# Episode 64: inference completed in 6 steps. Fidelity score: 0.9330127018922192
# Episode 65: inference completed in 3 steps. Fidelity score: 0.875
# Episode 67: inference completed in 12 steps. Fidelity score: 0.9330127018922187
# Episode 69: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 71: inference completed in 12 steps. Fidelity score: 0.8750000000000002
# Episode 73: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 74: inference completed in 17 steps. Fidelity score: 0.9330127018922196
# Episode 88: inference completed in 3 steps. Fidelity score: 0.933012701892219
# Episode 91: inference completed in 3 steps. Fidelity score: 0.9330127018922194
# Episode 93: inference completed in 3 steps. Fidelity score: 0.9330127018922194
# Episode 94: inference completed in 2 steps. Fidelity score: 0.9330127018922192
#
# |01> + |10>
#
# |00> - |11>
# Episode 47: inference completed in 15 steps. Fidelity score: 0.8600925490014673
# Episode 67: inference completed in 12 steps. Fidelity score: 0.8705127018922186
#
# |01> - |10>
# Episode 0: inference completed in 5 steps. Fidelity score: 0.8535533905932735
# Episode 13: inference completed in 18 steps. Fidelity score: 0.8705127018922186
# Episode 17: inference completed in 7 steps. Fidelity score: 0.8749999999999998
# Episode 41: inference completed in 10 steps. Fidelity score: 0.9330127018922192
#
#
# {'discount': 0.5, 'negative_reward': 0, 'positive_reward': 100.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 29: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 69: inference completed in 6 steps. Fidelity score: 0.9330127018922196
# Episode 76: inference completed in 6 steps. Fidelity score: 0.9330127018922196
#
# |01> + |10>
# Episode 3: inference completed in 8 steps. Fidelity score: 0.8750000000000002
# Episode 12: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 30: inference completed in 10 steps. Fidelity score: 0.9330127018922194
# Episode 86: inference completed in 14 steps. Fidelity score: 0.886137701892219
# Episode 91: inference completed in 15 steps. Fidelity score: 0.8535533905932737
#
# |00> - |11>
# Episode 18: inference completed in 18 steps. Fidelity score: 0.8960435549580872
# Episode 55: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 60: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 67: inference completed in 16 steps. Fidelity score: 0.8705127018922186
# Episode 76: inference completed in 6 steps. Fidelity score: 0.918258151868904
# Episode 78: inference completed in 12 steps. Fidelity score: 0.9182581518689036
# Episode 86: inference completed in 19 steps. Fidelity score: 0.9829629131445334
#
# |01> - |10>
# Episode 30: inference completed in 15 steps. Fidelity score: 0.8750000000000002
# Episode 44: inference completed in 9 steps. Fidelity score: 0.8535533905932733
# Episode 60: inference completed in 16 steps. Fidelity score: 0.8567465193097622
# Episode 89: inference completed in 14 steps. Fidelity score: 0.9999999999999998
# Episode 92: inference completed in 15 steps. Fidelity score: 0.9999999999999991
# Episode 93: inference completed in 15 steps. Fidelity score: 0.9999999999999991
#
#
# {'discount': 0.5, 'negative_reward': -5.0, 'positive_reward': 1, 'step_size': 0.0001}
# |00> + |11>
# Episode 6: inference completed in 16 steps. Fidelity score: 0.9098847396054318
# Episode 13: inference completed in 7 steps. Fidelity score: 0.933012701892219
# Episode 84: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 94: inference completed in 2 steps. Fidelity score: 0.9999999999999998
#
# |01> + |10>
# Episode 25: inference completed in 13 steps. Fidelity score: 0.8535533905932733
# Episode 80: inference completed in 9 steps. Fidelity score: 0.8705127018922191
#
# |00> - |11>
# Episode 4: inference completed in 6 steps. Fidelity score: 0.9330127018922192
# Episode 47: inference completed in 7 steps. Fidelity score: 0.8749999999999998
#
# |01> - |10>
# Episode 68: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 74: inference completed in 5 steps. Fidelity score: 0.9040063509461099
#
#
# {'discount': 0.5, 'negative_reward': -5.0, 'positive_reward': 1, 'step_size': 0.0005}
# |00> + |11>
# Episode 5: inference completed in 10 steps. Fidelity score: 0.9999999999999996
# Episode 75: inference completed in 14 steps. Fidelity score: 0.9009106354856411
#
# |01> + |10>
#
# |00> - |11>
# Episode 2: inference completed in 14 steps. Fidelity score: 0.8861377018922191
# Episode 50: inference completed in 14 steps. Fidelity score: 0.853553390593274
#
# |01> - |10>
#
#
# {'discount': 0.5, 'negative_reward': -5.0, 'positive_reward': 50.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 1: inference completed in 8 steps. Fidelity score: 0.9330127018922187
# Episode 3: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 36: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 41: inference completed in 15 steps. Fidelity score: 0.9374999999999997
# Episode 46: inference completed in 6 steps. Fidelity score: 0.8535533905932735
# Episode 82: inference completed in 19 steps. Fidelity score: 0.853553390593273
# Episode 87: inference completed in 2 steps. Fidelity score: 0.9999999999999998
#
# |01> + |10>
# Episode 7: inference completed in 16 steps. Fidelity score: 0.8705127018922193
# Episode 8: inference completed in 7 steps. Fidelity score: 0.8749999999999998
# Episode 71: inference completed in 12 steps. Fidelity score: 0.9173877018922193
#
# |00> - |11>
# Episode 94: inference completed in 8 steps. Fidelity score: 0.9330127018922194
#
# |01> - |10>
# Episode 12: inference completed in 11 steps. Fidelity score: 0.9419417382415922
# Episode 25: inference completed in 17 steps. Fidelity score: 0.878843606221842
#
#
# {'discount': 0.5, 'negative_reward': -5.0, 'positive_reward': 50.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 20: inference completed in 13 steps. Fidelity score: 0.9999999999999996
# Episode 60: inference completed in 13 steps. Fidelity score: 0.8705127018922193
#
# |01> + |10>
# Episode 52: inference completed in 18 steps. Fidelity score: 0.8705127018922191
# Episode 59: inference completed in 11 steps. Fidelity score: 0.8535533905932733
#
# |00> - |11>
# Episode 47: inference completed in 15 steps. Fidelity score: 0.853553390593274
# Episode 55: inference completed in 19 steps. Fidelity score: 0.933012701892219
# Episode 64: inference completed in 5 steps. Fidelity score: 0.9419417382415922
# Episode 72: inference completed in 10 steps. Fidelity score: 0.8705127018922191
# Episode 74: inference completed in 16 steps. Fidelity score: 0.933012701892219
# Episode 88: inference completed in 5 steps. Fidelity score: 0.8750000000000002
# Episode 93: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 94: inference completed in 5 steps. Fidelity score: 0.9592793267718457
#
# |01> - |10>
# Episode 9: inference completed in 12 steps. Fidelity score: 0.8705127018922193
# Episode 16: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Episode 17: inference completed in 5 steps. Fidelity score: 0.8749999999999998
# Episode 18: inference completed in 9 steps. Fidelity score: 0.9182581518689038
# Episode 23: inference completed in 8 steps. Fidelity score: 0.9182581518689038
# Episode 24: inference completed in 5 steps. Fidelity score: 0.9182581518689038
#
#
# {'discount': 0.5, 'negative_reward': -5.0, 'positive_reward': 100.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 60: inference completed in 17 steps. Fidelity score: 0.8705127018922193
# Episode 74: inference completed in 17 steps. Fidelity score: 0.9999999999999998
# Episode 79: inference completed in 14 steps. Fidelity score: 0.9330127018922194
# Episode 87: inference completed in 17 steps. Fidelity score: 0.8924760476065857
# Episode 98: inference completed in 12 steps. Fidelity score: 0.9330127018922192
#
# |01> + |10>
# Episode 9: inference completed in 18 steps. Fidelity score: 0.8535533905932737
# Episode 28: inference completed in 3 steps. Fidelity score: 0.9999999999999998
#
# |00> - |11>
#
# |01> - |10>
# Episode 18: inference completed in 11 steps. Fidelity score: 0.9769393933209523
# Episode 38: inference completed in 18 steps. Fidelity score: 0.8600360725625004
# Episode 63: inference completed in 19 steps. Fidelity score: 0.8878310524417866
# Episode 65: inference completed in 16 steps. Fidelity score: 0.85492034195238
# Episode 72: inference completed in 6 steps. Fidelity score: 0.9330127018922192
# Episode 74: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 82: inference completed in 14 steps. Fidelity score: 0.9171168834528286
# Episode 87: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 92: inference completed in 6 steps. Fidelity score: 0.9330127018922192
# Episode 96: inference completed in 8 steps. Fidelity score: 1.0
# Episode 98: inference completed in 8 steps. Fidelity score: 1.0
# Episode 99: inference completed in 8 steps. Fidelity score: 1.0
#
#
# {'discount': 0.5, 'negative_reward': -5.0, 'positive_reward': 100.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 8: inference completed in 13 steps. Fidelity score: 0.9009725748877031
# Episode 33: inference completed in 10 steps. Fidelity score: 0.9829629131445337
# Episode 40: inference completed in 12 steps. Fidelity score: 0.8535533905932733
# Episode 41: inference completed in 7 steps. Fidelity score: 0.9311862178478969
# Episode 43: inference completed in 9 steps. Fidelity score: 0.9829629131445341
# Episode 47: inference completed in 6 steps. Fidelity score: 0.8535533905932737
# Episode 51: inference completed in 6 steps. Fidelity score: 0.8535533905932737
# Episode 59: inference completed in 15 steps. Fidelity score: 0.8749999999999993
# Episode 60: inference completed in 9 steps. Fidelity score: 0.8535533905932733
# Episode 63: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 64: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 71: inference completed in 10 steps. Fidelity score: 0.8705127018922193
# Episode 73: inference completed in 10 steps. Fidelity score: 0.8705127018922195
# Episode 74: inference completed in 11 steps. Fidelity score: 0.933012701892219
# Episode 94: inference completed in 6 steps. Fidelity score: 0.8695994598700583
# Episode 97: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 99: inference completed in 14 steps. Fidelity score: 0.933012701892219
#
# |01> + |10>
# Episode 64: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 65: inference completed in 5 steps. Fidelity score: 0.9330127018922192
#
# |00> - |11>
# Episode 16: inference completed in 11 steps. Fidelity score: 0.9171168834528286
# Episode 72: inference completed in 16 steps. Fidelity score: 0.8535533905932731
#
# |01> - |10>
# Episode 1: inference completed in 15 steps. Fidelity score: 0.8705127018922195
# Episode 10: inference completed in 5 steps. Fidelity score: 0.9999999999999998
# Episode 14: inference completed in 7 steps. Fidelity score: 1.0
#
#
# {'discount': 0.75, 'negative_reward': 0, 'positive_reward': 1, 'step_size': 0.0001}
# |00> + |11>
# Episode 1: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 9: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 12: inference completed in 7 steps. Fidelity score: 0.9330127018922187
# Episode 17: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 23: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 25: inference completed in 3 steps. Fidelity score: 0.8535533905932737
# Episode 27: inference completed in 3 steps. Fidelity score: 0.8535533905932737
# Episode 30: inference completed in 15 steps. Fidelity score: 0.9506105325067187
# Episode 31: inference completed in 9 steps. Fidelity score: 0.8535533905932737
# Episode 32: inference completed in 8 steps. Fidelity score: 0.9999999999999996
# Episode 38: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Episode 44: inference completed in 8 steps. Fidelity score: 0.9330127018922196
# Episode 47: inference completed in 8 steps. Fidelity score: 0.9330127018922196
# Episode 51: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 61: inference completed in 8 steps. Fidelity score: 0.8705127018922193
# Episode 62: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 67: inference completed in 8 steps. Fidelity score: 0.8705127018922193
#
# |01> + |10>
# Episode 16: inference completed in 6 steps. Fidelity score: 0.9330127018922192
# Episode 24: inference completed in 6 steps. Fidelity score: 0.9330127018922192
# Episode 34: inference completed in 7 steps. Fidelity score: 0.9816713938910647
# Episode 41: inference completed in 6 steps. Fidelity score: 0.8535533905932733
# Episode 42: inference completed in 12 steps. Fidelity score: 0.8746994080239555
#
# |00> - |11>
#
# |01> - |10>
# Episode 12: inference completed in 15 steps. Fidelity score: 0.9173877018922193
# Episode 28: inference completed in 16 steps. Fidelity score: 0.8705127018922191
#
#
# {'discount': 0.75, 'negative_reward': 0, 'positive_reward': 1, 'step_size': 0.0005}
# |00> + |11>
#
# |01> + |10>
# Episode 20: inference completed in 5 steps. Fidelity score: 0.933012701892219
# Episode 28: inference completed in 5 steps. Fidelity score: 0.8705127018922193
# Episode 38: inference completed in 5 steps. Fidelity score: 0.9999999999999998
# Episode 65: inference completed in 5 steps. Fidelity score: 0.8749999999999998
# Episode 88: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 90: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 91: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 98: inference completed in 4 steps. Fidelity score: 0.9330127018922192
#
# |00> - |11>
#
# |01> - |10>
# Episode 58: inference completed in 14 steps. Fidelity score: 0.875
# Episode 59: inference completed in 13 steps. Fidelity score: 0.875
# Episode 71: inference completed in 15 steps. Fidelity score: 0.9330127018922196
# Episode 76: inference completed in 11 steps. Fidelity score: 0.9330127018922194
# Episode 81: inference completed in 8 steps. Fidelity score: 0.8705127018922193
# Episode 88: inference completed in 15 steps. Fidelity score: 0.8567465193097614
# Episode 89: inference completed in 15 steps. Fidelity score: 0.8567465193097614
# Episode 90: inference completed in 5 steps. Fidelity score: 0.9330127018922192
# Episode 96: inference completed in 8 steps. Fidelity score: 0.9829629131445339
#
#
# {'discount': 0.75, 'negative_reward': 0, 'positive_reward': 50.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 28: inference completed in 14 steps. Fidelity score: 0.933012701892219
#
# |01> + |10>
# Episode 26: inference completed in 9 steps. Fidelity score: 0.9330127018922187
# Episode 44: inference completed in 8 steps. Fidelity score: 0.9330127018922196
# Episode 51: inference completed in 5 steps. Fidelity score: 0.8750000000000002
# Episode 64: inference completed in 13 steps. Fidelity score: 0.8705127018922191
# Episode 68: inference completed in 13 steps. Fidelity score: 0.8705127018922191
# Episode 69: inference completed in 13 steps. Fidelity score: 0.8705127018922191
# Episode 85: inference completed in 9 steps. Fidelity score: 0.933012701892219
# Episode 87: inference completed in 7 steps. Fidelity score: 0.8705127018922191
#
# |00> - |11>
# Episode 11: inference completed in 11 steps. Fidelity score: 0.8749999999999993
# Episode 25: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 28: inference completed in 14 steps. Fidelity score: 0.9731756303964265
# Episode 30: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 33: inference completed in 18 steps. Fidelity score: 0.8535533905932735
# Episode 69: inference completed in 18 steps. Fidelity score: 0.9330127018922183
# Episode 87: inference completed in 18 steps. Fidelity score: 0.8932830462427465
# Episode 94: inference completed in 16 steps. Fidelity score: 0.8554077742438233
#
# |01> - |10>
#
#
# {'discount': 0.75, 'negative_reward': 0, 'positive_reward': 50.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 12: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 89: inference completed in 4 steps. Fidelity score: 0.9999999999999996
#
# |01> + |10>
# Episode 87: inference completed in 7 steps. Fidelity score: 0.9829629131445339
#
# |00> - |11>
# Episode 29: inference completed in 5 steps. Fidelity score: 0.9999999999999998
# Episode 33: inference completed in 4 steps. Fidelity score: 0.9999999999999998
#
# |01> - |10>
# Episode 39: inference completed in 13 steps. Fidelity score: 1.0
# Episode 41: inference completed in 9 steps. Fidelity score: 0.9999999999999998
# Episode 42: inference completed in 11 steps. Fidelity score: 0.9999999999999998
# Episode 61: inference completed in 17 steps. Fidelity score: 0.8749772200669051
# Episode 94: inference completed in 11 steps. Fidelity score: 0.9330127018922192
# Episode 95: inference completed in 13 steps. Fidelity score: 0.9040063509461095
# Episode 97: inference completed in 11 steps. Fidelity score: 0.9330127018922192
#
#
# {'discount': 0.75, 'negative_reward': 0, 'positive_reward': 100.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 6: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 10: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 23: inference completed in 8 steps. Fidelity score: 0.933012701892219
# Episode 24: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 25: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 29: inference completed in 9 steps. Fidelity score: 0.9330127018922192
# Episode 30: inference completed in 9 steps. Fidelity score: 0.8705127018922191
# Episode 33: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 34: inference completed in 8 steps. Fidelity score: 0.8750000000000004
# Episode 44: inference completed in 5 steps. Fidelity score: 0.9832531754730549
# Episode 45: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 57: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 58: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 60: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 61: inference completed in 16 steps. Fidelity score: 0.933012701892219
# Episode 62: inference completed in 10 steps. Fidelity score: 0.933012701892219
# Episode 63: inference completed in 9 steps. Fidelity score: 0.9330127018922185
# Episode 68: inference completed in 9 steps. Fidelity score: 0.9330127018922185
# Episode 73: inference completed in 12 steps. Fidelity score: 0.9341345264191646
# Episode 77: inference completed in 7 steps. Fidelity score: 0.8746994080239557
# Episode 80: inference completed in 10 steps. Fidelity score: 0.9257611141556922
# Episode 85: inference completed in 8 steps. Fidelity score: 0.8705127018922193
# Episode 94: inference completed in 11 steps. Fidelity score: 0.933012701892219
#
# |01> + |10>
# Episode 27: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 93: inference completed in 12 steps. Fidelity score: 0.8749999999999996
# Episode 99: inference completed in 18 steps. Fidelity score: 0.8750000000000002
#
# |00> - |11>
# Episode 47: inference completed in 13 steps. Fidelity score: 0.8535533905932733
# Episode 95: inference completed in 4 steps. Fidelity score: 0.8535533905932737
#
# |01> - |10>
# Episode 5: inference completed in 5 steps. Fidelity score: 0.9330127018922187
# Episode 12: inference completed in 10 steps. Fidelity score: 0.9999999999999998
# Episode 33: inference completed in 13 steps. Fidelity score: 0.8600925490014667
# Episode 98: inference completed in 19 steps. Fidelity score: 0.8705127018922197
# Episode 99: inference completed in 15 steps. Fidelity score: 0.9330127018922187
#
#
# {'discount': 0.75, 'negative_reward': 0, 'positive_reward': 100.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 3: inference completed in 4 steps. Fidelity score: 0.8749999999999998
# Episode 7: inference completed in 3 steps. Fidelity score: 0.8535533905932735
# Episode 26: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 37: inference completed in 4 steps. Fidelity score: 0.9330127018922194
# Episode 38: inference completed in 4 steps. Fidelity score: 0.9330127018922194
# Episode 41: inference completed in 18 steps. Fidelity score: 0.8716345264191645
# Episode 43: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 45: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 47: inference completed in 4 steps. Fidelity score: 1.0
# Episode 49: inference completed in 8 steps. Fidelity score: 0.9330127018922194
# Episode 51: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 54: inference completed in 4 steps. Fidelity score: 0.8750000000000002
# Episode 63: inference completed in 4 steps. Fidelity score: 0.8750000000000002
# Episode 64: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 71: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 80: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 82: inference completed in 3 steps. Fidelity score: 0.8535533905932737
# Episode 98: inference completed in 13 steps. Fidelity score: 0.9330127018922187
#
# |01> + |10>
# Episode 39: inference completed in 13 steps. Fidelity score: 0.9330127018922194
# Episode 96: inference completed in 15 steps. Fidelity score: 0.8746994080239553
#
# |00> - |11>
# Episode 11: inference completed in 9 steps. Fidelity score: 0.9182581518689038
# Episode 34: inference completed in 12 steps. Fidelity score: 0.9330127018922192
#
# |01> - |10>
# Episode 67: inference completed in 10 steps. Fidelity score: 0.8705127018922191
#
#
# {'discount': 0.75, 'negative_reward': -5.0, 'positive_reward': 1, 'step_size': 0.0001}
# |00> + |11>
# Episode 98: inference completed in 3 steps. Fidelity score: 0.8749999999999998
#
# |01> + |10>
#
# |00> - |11>
# Episode 27: inference completed in 17 steps. Fidelity score: 0.9829629131445337
# Episode 35: inference completed in 11 steps. Fidelity score: 0.8567465193097621
# Episode 46: inference completed in 6 steps. Fidelity score: 0.9999999999999998
# Episode 68: inference completed in 17 steps. Fidelity score: 0.8945745654962156
# Episode 85: inference completed in 10 steps. Fidelity score: 0.8749999999999998
# Episode 86: inference completed in 10 steps. Fidelity score: 0.8749999999999998
#
# |01> - |10>
#
#
# {'discount': 0.75, 'negative_reward': -5.0, 'positive_reward': 1, 'step_size': 0.0005}
# |00> + |11>
# Episode 87: inference completed in 15 steps. Fidelity score: 0.9171168834528277
#
# |01> + |10>
# Episode 68: inference completed in 7 steps. Fidelity score: 0.8535533905932737
# Episode 69: inference completed in 10 steps. Fidelity score: 0.8535533905932737
#
# |00> - |11>
# Episode 80: inference completed in 8 steps. Fidelity score: 0.8535533905932735
#
# |01> - |10>
#
#
# {'discount': 0.75, 'negative_reward': -5.0, 'positive_reward': 50.0, 'step_size': 0.0001}
# |00> + |11>
#
# |01> + |10>
#
# |00> - |11>
# Episode 68: inference completed in 11 steps. Fidelity score: 0.933012701892219
# Episode 73: inference completed in 15 steps. Fidelity score: 0.8888485857163401
# Episode 78: inference completed in 6 steps. Fidelity score: 0.8535533905932737
#
# |01> - |10>
# Episode 3: inference completed in 16 steps. Fidelity score: 0.9330127018922192
#
#
# {'discount': 0.75, 'negative_reward': -5.0, 'positive_reward': 50.0, 'step_size': 0.0005}
# |00> + |11>
#
# |01> + |10>
# Episode 46: inference completed in 18 steps. Fidelity score: 0.9330127018922194
#
# |00> - |11>
# Episode 40: inference completed in 4 steps. Fidelity score: 0.8749999999999998
#
# |01> - |10>
#
#
# {'discount': 0.75, 'negative_reward': -5.0, 'positive_reward': 100.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 42: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 53: inference completed in 9 steps. Fidelity score: 0.8749999999999998
# Episode 56: inference completed in 10 steps. Fidelity score: 0.9999999999999996
# Episode 62: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Episode 72: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 78: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 82: inference completed in 18 steps. Fidelity score: 0.9330127018922192
# Episode 88: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 91: inference completed in 18 steps. Fidelity score: 0.933635785577932
# Episode 93: inference completed in 6 steps. Fidelity score: 0.9999999999999998
#
# |01> + |10>
# Episode 21: inference completed in 18 steps. Fidelity score: 0.8535533905932733
# Episode 22: inference completed in 19 steps. Fidelity score: 0.9665063509461091
# Episode 23: inference completed in 4 steps. Fidelity score: 0.8535533905932737
# Episode 27: inference completed in 4 steps. Fidelity score: 0.8535533905932737
# Episode 29: inference completed in 11 steps. Fidelity score: 0.9330127018922192
# Episode 35: inference completed in 19 steps. Fidelity score: 0.9330127018922187
# Episode 39: inference completed in 3 steps. Fidelity score: 0.8535533905932735
# Episode 50: inference completed in 7 steps. Fidelity score: 0.9999999999999998
# Episode 62: inference completed in 14 steps. Fidelity score: 0.860092549001467
# Episode 65: inference completed in 7 steps. Fidelity score: 0.9999999999999993
# Episode 72: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 82: inference completed in 15 steps. Fidelity score: 0.8788436062218414
# Episode 85: inference completed in 15 steps. Fidelity score: 0.886137701892219
# Episode 95: inference completed in 5 steps. Fidelity score: 0.8535533905932737
#
# |00> - |11>
# Episode 8: inference completed in 15 steps. Fidelity score: 0.8535533905932735
#
# |01> - |10>
#
#
# {'discount': 0.75, 'negative_reward': -5.0, 'positive_reward': 100.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 7: inference completed in 5 steps. Fidelity score: 0.8750000000000002
# Episode 12: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 40: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Episode 44: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Episode 46: inference completed in 9 steps. Fidelity score: 0.8901650429449549
# Episode 97: inference completed in 14 steps. Fidelity score: 0.8535533905932733
#
# |01> + |10>
# Episode 12: inference completed in 6 steps. Fidelity score: 0.9171168834528286
# Episode 13: inference completed in 7 steps. Fidelity score: 0.895923174562532
# Episode 18: inference completed in 7 steps. Fidelity score: 0.8705127018922193
# Episode 20: inference completed in 7 steps. Fidelity score: 0.9171168834528288
# Episode 23: inference completed in 10 steps. Fidelity score: 0.9171168834528286
# Episode 38: inference completed in 6 steps. Fidelity score: 0.875
# Episode 41: inference completed in 6 steps. Fidelity score: 0.8750000000000002
# Episode 54: inference completed in 12 steps. Fidelity score: 0.8535533905932737
# Episode 58: inference completed in 17 steps. Fidelity score: 0.9731756303964252
# Episode 61: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 67: inference completed in 12 steps. Fidelity score: 0.8535533905932731
# Episode 69: inference completed in 6 steps. Fidelity score: 0.9182581518689036
# Episode 74: inference completed in 9 steps. Fidelity score: 0.8535533905932735
# Episode 81: inference completed in 17 steps. Fidelity score: 0.8723536013868004
# Episode 84: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 85: inference completed in 9 steps. Fidelity score: 0.8535533905932735
# Episode 88: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 92: inference completed in 8 steps. Fidelity score: 0.8535533905932737
# Episode 97: inference completed in 5 steps. Fidelity score: 0.8535533905932735
#
# |00> - |11>
#
# |01> - |10>
# Episode 2: inference completed in 8 steps. Fidelity score: 0.8535533905932735
# Episode 5: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Episode 47: inference completed in 19 steps. Fidelity score: 0.8705127018922193
#
#
# {'discount': 0.9, 'negative_reward': 0, 'positive_reward': 1, 'step_size': 0.0001}
# |00> + |11>
# Episode 1: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 3: inference completed in 6 steps. Fidelity score: 0.9040063509461095
# Episode 18: inference completed in 16 steps. Fidelity score: 0.875
# Episode 19: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 22: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 27: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 67: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 70: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 71: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 73: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 77: inference completed in 14 steps. Fidelity score: 0.9330127018922199
# Episode 78: inference completed in 19 steps. Fidelity score: 0.9015023816047909
# Episode 79: inference completed in 19 steps. Fidelity score: 0.9015023816047909
# Episode 90: inference completed in 2 steps. Fidelity score: 0.9330127018922192
#
# |01> + |10>
# Episode 14: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 18: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 32: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 42: inference completed in 4 steps. Fidelity score: 0.8535533905932735
# Episode 59: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 74: inference completed in 10 steps. Fidelity score: 0.9330127018922192
# Episode 79: inference completed in 19 steps. Fidelity score: 0.9999999999999996
#
# |00> - |11>
#
# |01> - |10>
# Episode 1: inference completed in 13 steps. Fidelity score: 0.8535533905932731
# Episode 84: inference completed in 9 steps. Fidelity score: 0.9171168834528286
#
#
# {'discount': 0.9, 'negative_reward': 0, 'positive_reward': 1, 'step_size': 0.0005}
# |00> + |11>
# Episode 51: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 86: inference completed in 13 steps. Fidelity score: 0.8721244274495474
#
# |01> + |10>
# Episode 73: inference completed in 14 steps. Fidelity score: 0.9330127018922194
#
# |00> - |11>
# Episode 0: inference completed in 7 steps. Fidelity score: 0.8705127018922191
# Episode 32: inference completed in 19 steps. Fidelity score: 0.9040063509461094
# Episode 91: inference completed in 10 steps. Fidelity score: 0.8535533905932733
# Episode 93: inference completed in 7 steps. Fidelity score: 0.8535533905932733
#
# |01> - |10>
# Episode 22: inference completed in 11 steps. Fidelity score: 0.9330127018922192
# Episode 31: inference completed in 16 steps. Fidelity score: 0.9171168834528284
# Episode 33: inference completed in 15 steps. Fidelity score: 0.9171168834528288
# Episode 65: inference completed in 11 steps. Fidelity score: 0.9130728358731021
# Episode 66: inference completed in 9 steps. Fidelity score: 0.9171168834528289
# Episode 67: inference completed in 9 steps. Fidelity score: 0.9171168834528289
# Episode 69: inference completed in 12 steps. Fidelity score: 0.8535533905932735
#
#
# {'discount': 0.9, 'negative_reward': 0, 'positive_reward': 50.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 38: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 43: inference completed in 14 steps. Fidelity score: 0.9075025109568593
# Episode 46: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 54: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 59: inference completed in 2 steps. Fidelity score: 0.9330127018922192
#
# |01> + |10>
#
# |00> - |11>
#
# |01> - |10>
#
#
# {'discount': 0.9, 'negative_reward': 0, 'positive_reward': 50.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 0: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 17: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 39: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 48: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 53: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 91: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 95: inference completed in 2 steps. Fidelity score: 0.8535533905932735
#
# |01> + |10>
#
# |00> - |11>
# Episode 32: inference completed in 19 steps. Fidelity score: 0.8939502018922186
# Episode 50: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 57: inference completed in 14 steps. Fidelity score: 0.8705127018922195
#
# |01> - |10>
# Episode 61: inference completed in 6 steps. Fidelity score: 0.8749999999999998
#
#
# {'discount': 0.9, 'negative_reward': 0, 'positive_reward': 100.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 8: inference completed in 3 steps. Fidelity score: 0.9999999999999998
# Episode 15: inference completed in 4 steps. Fidelity score: 0.933012701892219
# Episode 26: inference completed in 10 steps. Fidelity score: 0.9829629131445341
# Episode 27: inference completed in 6 steps. Fidelity score: 0.9330127018922187
# Episode 28: inference completed in 6 steps. Fidelity score: 0.9330127018922187
# Episode 29: inference completed in 8 steps. Fidelity score: 0.9999999999999991
# Episode 31: inference completed in 11 steps. Fidelity score: 0.875
# Episode 32: inference completed in 8 steps. Fidelity score: 0.9999999999999991
# Episode 33: inference completed in 8 steps. Fidelity score: 0.9999999999999991
# Episode 37: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 39: inference completed in 5 steps. Fidelity score: 0.933012701892219
# Episode 40: inference completed in 6 steps. Fidelity score: 0.9999999999999998
# Episode 41: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 43: inference completed in 6 steps. Fidelity score: 0.933012701892219
# Episode 44: inference completed in 5 steps. Fidelity score: 0.933012701892219
# Episode 46: inference completed in 6 steps. Fidelity score: 0.9999999999999998
# Episode 48: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 59: inference completed in 6 steps. Fidelity score: 0.8535533905932735
# Episode 60: inference completed in 5 steps. Fidelity score: 0.853553390593274
# Episode 65: inference completed in 5 steps. Fidelity score: 0.853553390593274
# Episode 91: inference completed in 7 steps. Fidelity score: 0.8535533905932733
# Episode 92: inference completed in 6 steps. Fidelity score: 0.8535533905932735
# Episode 94: inference completed in 6 steps. Fidelity score: 0.9829629131445339
#
# |01> + |10>
# Episode 94: inference completed in 16 steps. Fidelity score: 0.9171168834528284
#
# |00> - |11>
# Episode 5: inference completed in 14 steps. Fidelity score: 0.8535533905932735
# Episode 57: inference completed in 5 steps. Fidelity score: 0.9182581518689036
# Episode 64: inference completed in 5 steps. Fidelity score: 0.8535533905932733
# Episode 70: inference completed in 5 steps. Fidelity score: 0.9375000000000001
# Episode 76: inference completed in 14 steps. Fidelity score: 0.9451576468911741
# Episode 84: inference completed in 5 steps. Fidelity score: 0.933012701892219
# Episode 91: inference completed in 13 steps. Fidelity score: 0.9040063509461094
# Episode 98: inference completed in 8 steps. Fidelity score: 0.9341345264191644
#
# |01> - |10>
#
#
# {'discount': 0.9, 'negative_reward': 0, 'positive_reward': 100.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 28: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 30: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 32: inference completed in 3 steps. Fidelity score: 0.8749999999999998
# Episode 33: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 35: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 40: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 51: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 58: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 65: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 67: inference completed in 14 steps. Fidelity score: 0.8535533905932731
# Episode 71: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 72: inference completed in 8 steps. Fidelity score: 0.933012701892219
# Episode 73: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 76: inference completed in 8 steps. Fidelity score: 0.933012701892219
# Episode 77: inference completed in 8 steps. Fidelity score: 0.933012701892219
# Episode 83: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 85: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 86: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 89: inference completed in 3 steps. Fidelity score: 0.8535533905932735
# Episode 90: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 94: inference completed in 16 steps. Fidelity score: 0.8705127018922191
#
# |01> + |10>
# Episode 56: inference completed in 4 steps. Fidelity score: 0.9999999999999998
# Episode 73: inference completed in 15 steps. Fidelity score: 0.8705127018922191
#
# |00> - |11>
# Episode 36: inference completed in 13 steps. Fidelity score: 0.875
# Episode 68: inference completed in 14 steps. Fidelity score: 1.0
#
# |01> - |10>
#
#
# {'discount': 0.9, 'negative_reward': -5.0, 'positive_reward': 1, 'step_size': 0.0001}
# |00> + |11>
#
# |01> + |10>
# Episode 5: inference completed in 16 steps. Fidelity score: 0.8664648601747738
#
# |00> - |11>
# Episode 14: inference completed in 15 steps. Fidelity score: 0.8998196448143736
# Episode 40: inference completed in 7 steps. Fidelity score: 0.9330127018922192
# Episode 43: inference completed in 5 steps. Fidelity score: 0.8535533905932737
#
# |01> - |10>
# Episode 25: inference completed in 18 steps. Fidelity score: 0.8861377018922195
# Episode 69: inference completed in 12 steps. Fidelity score: 0.9999999999999998
#
#
# {'discount': 0.9, 'negative_reward': -5.0, 'positive_reward': 1, 'step_size': 0.0005}
# |00> + |11>
# Episode 58: inference completed in 6 steps. Fidelity score: 0.9330127018922194
#
# |01> + |10>
# Episode 24: inference completed in 7 steps. Fidelity score: 0.9330127018922194
#
# |00> - |11>
# Episode 24: inference completed in 15 steps. Fidelity score: 0.9171168834528284
#
# |01> - |10>
# Episode 60: inference completed in 16 steps. Fidelity score: 0.9056980334736949
# Episode 95: inference completed in 9 steps. Fidelity score: 0.9171168834528286
#
#
# {'discount': 0.9, 'negative_reward': -5.0, 'positive_reward': 50.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 24: inference completed in 3 steps. Fidelity score: 0.9330127018922194
# Episode 28: inference completed in 13 steps. Fidelity score: 0.8749999999999998
# Episode 31: inference completed in 3 steps. Fidelity score: 0.9330127018922194
# Episode 34: inference completed in 3 steps. Fidelity score: 0.8535533905932735
# Episode 35: inference completed in 6 steps. Fidelity score: 0.9330127018922196
# Episode 62: inference completed in 4 steps. Fidelity score: 0.9330127018922194
# Episode 65: inference completed in 4 steps. Fidelity score: 0.9330127018922192
# Episode 67: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 70: inference completed in 3 steps. Fidelity score: 0.933012701892219
# Episode 72: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Episode 79: inference completed in 4 steps. Fidelity score: 0.933012701892219
# Episode 87: inference completed in 3 steps. Fidelity score: 0.8535533905932735
#
# |01> + |10>
# Episode 18: inference completed in 5 steps. Fidelity score: 0.875
# Episode 51: inference completed in 14 steps. Fidelity score: 0.8705127018922191
# Episode 68: inference completed in 5 steps. Fidelity score: 0.9999999999999998
#
# |00> - |11>
# Episode 95: inference completed in 15 steps. Fidelity score: 0.9330127018922194
#
# |01> - |10>
# Episode 6: inference completed in 12 steps. Fidelity score: 0.8535533905932733
#
#
# {'discount': 0.9, 'negative_reward': -5.0, 'positive_reward': 50.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 13: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 14: inference completed in 9 steps. Fidelity score: 0.8535533905932735
# Episode 23: inference completed in 10 steps. Fidelity score: 0.9832531754730547
# Episode 60: inference completed in 4 steps. Fidelity score: 0.875
# Episode 61: inference completed in 5 steps. Fidelity score: 0.875
#
# |01> + |10>
# Episode 63: inference completed in 17 steps. Fidelity score: 0.8872595264191641
# Episode 85: inference completed in 10 steps. Fidelity score: 0.8535533905932737
# Episode 89: inference completed in 10 steps. Fidelity score: 0.8535533905932735
#
# |00> - |11>
# Episode 35: inference completed in 14 steps. Fidelity score: 0.8705127018922191
# Episode 36: inference completed in 14 steps. Fidelity score: 0.9364344058641356
# Episode 64: inference completed in 9 steps. Fidelity score: 0.875
#
# |01> - |10>
# Episode 68: inference completed in 11 steps. Fidelity score: 0.933012701892219
# Episode 69: inference completed in 11 steps. Fidelity score: 0.933012701892219
# Episode 84: inference completed in 6 steps. Fidelity score: 0.8750000000000002
#
#
# {'discount': 0.9, 'negative_reward': -5.0, 'positive_reward': 100.0, 'step_size': 0.0001}
# |00> + |11>
# Episode 12: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 45: inference completed in 11 steps. Fidelity score: 0.8716345264191645
# Episode 89: inference completed in 16 steps. Fidelity score: 0.8705127018922195
#
# |01> + |10>
# Episode 26: inference completed in 5 steps. Fidelity score: 0.9171168834528284
# Episode 55: inference completed in 14 steps. Fidelity score: 0.8742370920296013
# Episode 85: inference completed in 13 steps. Fidelity score: 0.8727007566408584
#
# |00> - |11>
# Episode 65: inference completed in 4 steps. Fidelity score: 0.9330127018922192
#
# |01> - |10>
#
#
# {'discount': 0.9, 'negative_reward': -5.0, 'positive_reward': 100.0, 'step_size': 0.0005}
# |00> + |11>
# Episode 6: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 25: inference completed in 3 steps. Fidelity score: 0.875
# Episode 32: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 48: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 94: inference completed in 3 steps. Fidelity score: 0.8535533905932735
# Episode 97: inference completed in 3 steps. Fidelity score: 0.8535533905932735
#
# |01> + |10>
# Episode 11: inference completed in 13 steps. Fidelity score: 0.9028802437291185
# Episode 55: inference completed in 7 steps. Fidelity score: 0.8535533905932733
# Episode 76: inference completed in 6 steps. Fidelity score: 0.9330127018922196
# Episode 84: inference completed in 19 steps. Fidelity score: 0.8872170184853143
#
# |00> - |11>
# Episode 69: inference completed in 13 steps. Fidelity score: 0.8886047162271478
#
# |01> - |10>
#
#
# CPU times: user 41min 41s, sys: 30 s, total: 42min 11s
# Wall time: 42min 16s

# %%
path = "tuning.txt"

with open(path, 'w+') as f:
  f.write("Arguments \n")
  f.write(f"Tolerance: {TOLERANCE} - Training episodes: {TRAINING_EPISODES} - Offline updates: {NUM_OFFLINE_UPDATES}\n\n")

  f.write("\t".join(["Bell state", "parameters", "number of gates", "fidelity", "optimality_type"]))
  f.write("\n")
  for col in gridsearch_df:
    f.write(col + "\t")
    f.write(f"{gridsearch_df.loc['params', col][np.argmin(gridsearch_df.loc['num_gates', col])]}\t")
    f.write(f"{gridsearch_df.loc['num_gates', col][np.argmin(gridsearch_df.loc['num_gates', col])]}\t")
    f.write(f"{gridsearch_df.loc['fidelity', col][np.argmin(gridsearch_df.loc['num_gates', col])]}\t")
    f.write("num_gates \n")

    f.write(col + "\t")
    f.write(f"{gridsearch_df.loc['params', col][np.argmax(gridsearch_df.loc['fidelity', col])]}\t")
    f.write(f"{gridsearch_df.loc['num_gates', col][np.argmax(gridsearch_df.loc['fidelity', col])]}\t")
    f.write(f"{gridsearch_df.loc['fidelity', col][np.argmax(gridsearch_df.loc['fidelity', col])]}\t")
    f.write("fidelity \n")
    f.write("\n")

# %%
files.download(path)

# %% [markdown]
# ### Train

# %%
TOLERANCE = 0.15
TRAINING_EPISODES = 100
NUM_OFFLINE_UPDATES = 0 # WAY WORSE IF != 0

STEP_SIZE = 0.0001
NEG_REWARD = -1.
POS_REWARD = 100.
DISCOUNT = 0.
EPS = 1
PATH = 'logs.txt'

# %%
with open(PATH, "w+") as f:
  f.write(f"TOLERANCE: {TOLERANCE}\n")
  # f.write(f"TRAINING_EPISODES: {TRAINING_EPISODES}\n")
  f.write(f"STEP_SIZE: {STEP_SIZE}\n")
  f.write(f"NUM_OFFLINE_UPDATES: {NUM_OFFLINE_UPDATES}\n")
  f.write(f"NEG_REWARD: {NEG_REWARD}\n")
  f.write(f"POS_REWARD: {POS_REWARD}\n")
  f.write(f"DISCOUNT: {DISCOUNT}\n")
  f.write(f"DISCOUNT: {EPS}\n")

# %%
W = None

for rep, bell_state in bell_dict.items():
  print("Bell state: " +  rep)
  start = [1, 0, 0, 0]
  target = bell_state

  experiment = Experiment(start, target, TOLERANCE, TRAINING_EPISODES, STEP_SIZE,
                          NUM_OFFLINE_UPDATES, NEG_REWARD, POS_REWARD,
                          DISCOUNT, EPS)
  circuit_gates, terminal_state = experiment.run_experiment()
  compare_circuits(circuit_gates, terminal_state, QuantumState(target))
  print()

  sns.heatmap(experiment._agent._W)
  plt.show()
  print()
  print()
# Out:
# Bell state: |00> + |11>
# Episode 5: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 7: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 8: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 14: inference completed in 14 steps. Fidelity score: 0.8705127018922197
# Episode 15: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 19: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 33: inference completed in 2 steps. Fidelity score: 0.8535533905932735
# Episode 35: inference completed in 3 steps. Fidelity score: 0.8749999999999998
# Episode 43: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 48: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 49: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 51: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 54: inference completed in 2 steps. Fidelity score: 0.9999999999999998
# Episode 66: inference completed in 3 steps. Fidelity score: 0.933012701892219
# Episode 67: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 71: inference completed in 3 steps. Fidelity score: 0.8749999999999998
# Episode 78: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 83: inference completed in 2 steps. Fidelity score: 0.9330127018922192
# Episode 96: inference completed in 3 steps. Fidelity score: 0.9330127018922192
# Approximate state: [0.707 0.    0.    0.707]
# Target state: [0.707 0.    0.    0.707]
# Fidelity score: 0.9999999999999998. Number of gates: 2
#
# q0: ───Ry(0.5π)───@───
#                   │
# q1: ───I──────────X───
# Bell state: |01> + |10>
# Episode 16: inference completed in 13 steps. Fidelity score: 0.8705127018922191
# Episode 31: inference completed in 8 steps. Fidelity score: 0.9330127018922192
# Approximate state: [-0.   +0.j     0.183+0.683j -0.183+0.683j -0.   -0.j   ]
# Target state: [0.    0.707 0.707 0.   ]
# Fidelity score: 0.9330127018922192. Number of gates: 8
#
# q0: ───Ry(π)───Rx(0.5π)───I──────────Rx(π)───I──────────I──────────Rz(0.667π)───@───
#                                                                                 │
# q1: ───I───────I──────────Rz(0.5π)───I───────Rx(0.5π)───Rx(0.5π)───I────────────X───
# Bell state: |00> - |11>
# Episode 32: inference completed in 6 steps. Fidelity score: 0.8749999999999998
# Approximate state: [ 0.75-0.433j -0.  -0.j     0.  -0.j    -0.25+0.433j]
# Target state: [ 0.707  0.     0.    -0.707]
# Fidelity score: 0.8749999999999998. Number of gates: 6
#
# q0: ───I───────I───────Rx(0.333π)───Rz(0.667π)───Rz(0.667π)───@───
#                                                               │
# q1: ───Rx(π)───Ry(π)───I────────────I────────────I────────────X───
# Bell state: |01> - |10>
# Episode 6: inference completed in 18 steps. Fidelity score: 0.860092549001467
# Approximate state: [-0.152-0.198j  0.591-0.296j -0.495+0.439j -0.231+0.096j]
# Target state: [ 0.     0.707 -0.707  0.   ]
# Fidelity score: 0.860092549001467. Number of gates: 18
#
# q0: ───Ry(π)───I────────────Rx(0.5π)───I───────I──────────I────────────I────────────I────────────I────────────Rz(0.25π)───@───I──────────I────────────Rz(0.25π)───I────────────I────────────I──────────Rz(0.25π)───
#                                                                                                                           │
# q1: ───I───────Rz(0.333π)───I──────────Ry(π)───Ry(0.5π)───Rz(0.333π)───Rz(0.333π)───Rz(0.333π)───Rz(0.333π)───I───────────X───Ry(0.5π)───Rz(0.667π)───I───────────Rz(0.667π)───Rx(0.667π)───Ry(0.5π)───I───────────

# %%
files.download(PATH)
